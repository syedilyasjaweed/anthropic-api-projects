# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"],
}

# %%
messages = []
add_user_message(
    messages,
    """
    What are the different types of push ups?
    """,
)
response = chat(messages)
response
# Out:
# Message(id='msg_01FHbanZSvU54Ykbp2Qduyxt', container=None, content=[TextBlock(citations=None, text='# Different Types of Push-Ups\n\nThere are many push-up variations that target different muscle groups and difficulty levels:\n\n## **Basic Variations**\n- **Standard Push-Up** - Classic form, hands shoulder-width apart\n- **Wide Push-Up** - Hands placed wider than shoulders (emphasizes chest)\n- **Close/Diamond Push-Up** - Hands close together forming a diamond (targets triceps)\n- **Incline Push-Up** - Hands elevated on a surface (easier, beginner-friendly)\n- **Decline Push-Up** - Feet elevated (harder, more shoulder emphasis)\n\n## **Advanced Variations**\n- **Plyometric/Clap Push-Up** - Explosive push with hands leaving ground\n- **One-Arm Push-Up** - Performed on single arm\n- **Archer Push-Up** - Shift weight side to side\n- **Pseudo Planche Push-Up** - Hands positioned lower near hips\n- **Superman Push-Up** - Arms and legs lift off ground\n\n## **Functional Variations**\n- **T Push-Up** - Rotate into side plank at top\n- **Spiderman Push-Up** - Bring knee to elbow while descending\n- **Pike Push-Up** - Hips elevated (targets shoulders)\n- **Staggered Push-Up** - Hands at different heights\n\n## **Equipment-Based**\n- **Medicine Ball Push-Up**\n- **TRX/Suspension Push-Up**\n- **Knuckle Push-Up** - On fists instead of palms\n\nEach variation offers unique benefits for strength, power, or targeting specific muscles!', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=21, output_tokens=382, server_tool_use=None, service_tier='standard'))

# %%
messages = []
add_user_message(messages, "What are the different types of push ups?")
response = chat(messages)

# Add this line ↓
print(text_from_message(response))
# Out:
# # Types of Push-Ups
#
# Here are the main variations, organized by difficulty:
#
# ## **Beginner/Modified**
# - **Wall push-ups** - performed standing against a wall
# - **Incline push-ups** - hands elevated on bench/surface
# - **Knee push-ups** - performed on knees instead of toes
#
# ## **Standard**
# - **Regular push-ups** - classic form, hands shoulder-width apart
#
# ## **Intermediate**
# - **Wide push-ups** - hands placed wider than shoulders
# - **Diamond/Close-grip push-ups** - hands form diamond shape
# - **Decline push-ups** - feet elevated on surface
# - **Pike push-ups** - hips raised, targeting shoulders
# - **Staggered push-ups** - hands at different heights
#
# ## **Advanced**
# - **One-arm push-ups** - entire body weight on one arm
# - **Plyometric/Clap push-ups** - explosive power with hand clap
# - **Archer push-ups** - weight shifts side to side
# - **Pseudo planche push-ups** - hands by hips, lean forward
# - **Handstand push-ups** - inverted against wall
#
# ## **Specialty Variations**
# - **Spiderman push-ups** - knee to elbow during descent
# - **T push-ups** - rotate into side plank
# - **Hindu push-ups** - scooping motion forward and up
#
# Each variation targets muscles differently, so mixing them up provides a well-rounded workout!
